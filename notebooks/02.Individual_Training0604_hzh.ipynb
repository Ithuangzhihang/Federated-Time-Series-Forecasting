# %% [markdown]
# ### In this notebook we perform individual training.
# In individual learning each base station has access only to it's private dataset.

# %%
import sys
import os

from pathlib import Path

parent = Path(os.path.abspath("")).resolve().parents[0]
if parent not in sys.path:
    sys.path.insert(0, str(parent))

# %%
import random

import numpy as np
import torch

from argparse import Namespace

# %%
from ml.utils.data_utils import read_data, generate_time_lags, time_to_feature, handle_nans, to_Xy, \
    to_torch_dataset, to_timeseries_rep, assign_statistics, \
    to_train_val, scale_features, get_data_by_area, remove_identifiers, get_exogenous_data_by_area, handle_outliers

# %%
from ml.utils.train_utils import train, test

# %%
from ml.models.mlp import MLP
from ml.models.rnn import RNN
from ml.models.lstm import LSTM
from ml.models.gru import GRU
from ml.models.cnn import CNN
from ml.models.rnn_autoencoder import DualAttentionAutoEncoder

# %%
args = Namespace(
    data_path='/home/yanglin/Federated-Time-Series-Forecasting/dataset/processed_A032_IGVData_KPI.csv', # 数据集路径
    data_path_test=['../dataset/ElBorn_test.csv'], # 测试数据集路径
    test_size=0.2, # 验证集的比例
    targets=['charge_status'], # 目标列
    num_lags=10, # 输入中包括的过去观测值的数量

    filter_bs=None, # 是否在训练中使用单一基站，可动态变化
    identifier='vehicle_id', # 用于识别基站的列名

    nan_constant=0, # 用于转换NaN值的常数
    x_scaler='minmax', # x轴数据的缩放器
    y_scaler='minmax', # y轴数据的缩放器
    outlier_detection=None, # 是否执行异常值检测（如数据截断）

    criterion='mse', # 优化标准，可以是mse（均方误差）或l1
    epochs=150, # 最大迭代轮数
    lr=0.001, # 学习率
    optimizer='adam', # 优化器，可选sgd或adam
    batch_size=128, # 批处理大小
    early_stopping=True, # 是否使用提前停止
    patience=50, # 提前停止的耐心值
    max_grad_norm=0.0, # 是否剪辑梯度范数
    reg1=0.0, # L1正则化
    reg2=0.0, # L2正则化

    plot_history=True, # 是否绘制损失历史图

    cuda=True, # 是否使用GPU

    seed=0, # 可重现性种子

    assign_stats=None, # 是否使用统计数据作为外源数据，可选["mean", "median", "std", "variance", "kurtosis", "skew"]
    use_time_features=False # 是否使用时间特征，即从时序特征中提取时间特征
)

# %% [markdown]
# > You can define the base station to perform train on the filter_bs parameter and use it in block 12 or you can define the base station to block 12 explicitly

# %%
print(f"Script arguments: {args}\n")
# Out:
# Script arguments: Namespace(assign_stats=None, batch_size=128, criterion='mse', cuda=True, data_path='/home/yanglin/Federated-Time-Series-Forecasting/dataset/processed_A032_IGVData_KPI.csv', data_path_test=['../dataset/ElBorn_test.csv'], early_stopping=True, epochs=150, filter_bs=None, identifier='vehicle_id', lr=0.001, max_grad_norm=0.0, nan_constant=0, num_lags=10, optimizer='adam', outlier_detection=None, patience=50, plot_history=True, reg1=0.0, reg2=0.0, seed=0, targets=['charge_status'], test_size=0.2, use_time_features=False, x_scaler='minmax', y_scaler='minmax')

# %%
device = "cuda" if args.cuda and torch.cuda.is_available() else "cpu"
print(f"Using {device}")
# Out:
# Using cpu

# %%
#TODO: 这里不需要执行
# Outlier detection specification
if args.outlier_detection is not None:
    outlier_columns = ['rb_down', 'rb_up', 'down', 'up']
    outlier_kwargs = {"ElBorn": (10, 90), "LesCorts": (10, 90), "PobleSec": (5, 95)}
    args.outlier_columns = outlier_columns
    args.outlier_kwargs = outlier_kwargs

# %%
def seed_all():
    # ensure reproducibility
    random.seed(args.seed)
    np.random.seed(args.seed)
    torch.manual_seed(args.seed)
    torch.cuda.manual_seed_all(args.seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
seed_all()

# %% [markdown]
# ## 在这里为filter_bs参数中指定的基站执行预处理管道
# 预处理中的:
# 1. nan处理
# 2. 异常值处理
# 3. 扩展数据
# 4. 产生时间滞后
# 5. 生成和导入外生数据作为特征(时间、统计数据)(如果适用)

# %%
def make_preprocessing(filter_bs=None):
    """预处理给定的 .csv"""
    # 读取数据
    df = read_data(args.data_path, filter_data=filter_bs)
    print(f"数据形状: {df.shape}")
    # 处理缺失值
    df = handle_nans(train_data=df, constant=args.nan_constant,
                     identifier=args.identifier)
    print(f"处理缺失值后的数据形状: {df.shape}")
    # 分割训练集和验证集
    train_data, val_data = to_train_val(df)
    print(f"训练集数据形状: {train_data.shape}")
    print(f"验证集数据形状: {val_data.shape}")
    
    # 获取目标变量的索引，在fit中使用
    target_column = args.targets[0]
    target_index = df.columns.get_loc(target_column)
    print(f"目标变量 {target_column} 的索引是: {target_index}")
    
    # 异常值处理（如果指定）
    print(f"异常值检测: {args.outlier_detection}")
    # TODO:目前不需要异常值检测，如果后续需要异常值检测，再进行修改
    if args.outlier_detection is not None:
        train_data = handle_outliers(df=train_data, columns=args.outlier_columns,
                                     identifier=args.identifier, kwargs=args.outlier_kwargs)
    
    # 将数据集划分为特征（X）和目标变量（y）
    # TODO: 这里y_val把小车id也加进去了 
    X_train, X_val, y_train, y_val = to_Xy(train_data=train_data, val_data=val_data,
                                          targets=args.targets)
    print(f"X_train 形状: {X_train.shape}")
    print(f"y_train 形状: {y_train.shape}")
    print(f"X_val 形状: {X_val.shape}")
    print(f"y_val 形状: {y_val.shape}")
    print(f"y_train.ndim:{y_train.ndim}")
        
  
    
    # 标准化处理特征与目标变量
    # 标准化 X
    X_train, X_val, x_scaler = scale_features(train_data=X_train, val_data=X_val,
                                             scaler=args.x_scaler, identifier=args.identifier)
    print(f"标准化后 X_train 形状: {X_train.shape}")
    print(f"标准化后 X_val 形状: {X_val.shape}")
    print(f"X_scaler: {x_scaler}")
    # 标准化 y
    y_train, y_val, y_scaler = scale_features(train_data=y_train, val_data=y_val,
                                             scaler=args.y_scaler, identifier=args.identifier)
    print(f"标准化后 y_train 形状: {y_train.shape}")
    print(f"标准化后 y_val 形状: {y_val.shape}")
    print(f"y_scaler: {y_scaler}")
    # 生成时间滞后
    X_train = generate_time_lags(X_train, args.num_lags)
    X_val = generate_time_lags(X_val, args.num_lags)
    y_train = generate_time_lags(y_train, args.num_lags, is_y=True)
    y_val = generate_time_lags(y_val, args.num_lags, is_y=True)
    print(f"生成时间滞后后 X_train 形状: {X_train.shape}")
    print(f"生成时间滞后后 X_val 形状: {X_val.shape}")
    print(f"生成时间滞后后 y_train 形状: {y_train.shape}")
    print(f"生成时间滞后后 y_val 形状: {y_val.shape}")
    # 获取日期时间特征作为外生数据，这里目前是没有执行的。根据参数来看
    date_time_df_train = time_to_feature(
        X_train, args.use_time_features, identifier=args.identifier
    )
    date_time_df_val = time_to_feature(
        X_val, args.use_time_features, identifier=args.identifier
    )
    print(f"日期时间特征训练集: {date_time_df_train}")
    print(f"日期时间特征验证集: {date_time_df_val}")
    # 获取统计数据作为外生数据
    stats_df_train = assign_statistics(X_train, args.assign_stats, args.num_lags,
                                       targets=args.targets, identifier=args.identifier)
    print(f"统计数据训练集: {stats_df_train}")
    stats_df_val = assign_statistics(X_val, args.assign_stats, args.num_lags, 
                                       targets=args.targets, identifier=args.identifier)
    print(f"统计数据验证集: {stats_df_val}")
    # 将外生特征（如果有）连接到一个数据框中
    if date_time_df_train is not None or stats_df_train is not None:
        exogenous_data_train = pd.concat([date_time_df_train, stats_df_train], axis=1)
        # 移除重复列（如果有）
        exogenous_data_train = exogenous_data_train.loc[:, ~exogenous_data_train.columns.duplicated()].copy()
        assert len(exogenous_data_train) == len(X_train) == len(y_train)
    else:
        exogenous_data_train = None
    if date_time_df_val is not None or stats_df_val is not None:
        exogenous_data_val = pd.concat([date_time_df_val, stats_df_val], axis=1)
        exogenous_data_val = exogenous_data_val.loc[:, ~exogenous_data_val.columns.duplicated()].copy()
        assert len(exogenous_data_val) == len(X_val) == len(y_val)
    else:
        exogenous_data_val = None
        
    return X_train, X_val, y_train, y_val, exogenous_data_train, exogenous_data_val, x_scaler, y_scaler,target_index

# %%
# 因为没有从时序特征中提取时间特征，所以 exogenous_data_train,exogenous_data_valde的值是空的
X_train, X_val, y_train, y_val, exogenous_data_train, exogenous_data_val, x_scaler, y_scaler,target_index = make_preprocessing(
    
)

# make_preprocessing(
#      filter_bs="LesCorts"
#  )
# Out:
# INFO logger 2024-06-04 12:47:55,638 | data_utils.py:51 | 缺失值处理执行了，填充值为0
# 数据形状: (11039, 27)
# 处理缺失值后的数据形状: (11039, 27)
# 数据的样本信息:
# 	总样本数: 11039
# 	训练样本数: 8832
# 	验证样本数: 2207
# 训练集数据形状: (8832, 27)
# 验证集数据形状: (2207, 27)
# 目标变量 charge_status 的索引是: 13
# 异常值检测: None
# X_train 形状: (8832, 27)
# y_train 形状: (8832, 2)
# X_val 形状: (2207, 27)
# y_val 形状: (2207, 2)
# y_train.ndim:2
# 标准化后 X_train 形状: (8832, 27)
# 标准化后 X_val 形状: (2207, 27)
# X_scaler: MinMaxScaler()
# 标准化后 y_train 形状: (8832, 2)
# 标准化后 y_val 形状: (2207, 2)
# y_scaler: MinMaxScaler()
# Processing area: 0.0, initial shape: (8832, 27)
# Generated lag-1 for column position_x, shape: (8832, 28)
# Generated lag-1 for column position_y, shape: (8832, 29)
# Generated lag-1 for column position_z, shape: (8832, 30)
# Generated lag-1 for column heading, shape: (8832, 31)
# Generated lag-1 for column speed, shape: (8832, 32)
# Generated lag-1 for column speed_command, shape: (8832, 33)
# Generated lag-1 for column mileage_distance, shape: (8832, 34)
# Generated lag-1 for column power_on_time, shape: (8832, 35)
# Generated lag-1 for column soc, shape: (8832, 36)
# Generated lag-1 for column fuel_level, shape: (8832, 37)
# Generated lag-1 for column chassis_mode, shape: (8832, 38)
# Generated lag-1 for column estop, shape: (8832, 39)
# Generated lag-1 for column charge_status, shape: (8832, 40)
# Generated lag-1 for column task_state_running, shape: (8832, 41)
# Generated lag-1 for column task_state_estop, shape: (8832, 42)
# Generated lag-1 for column task_state_lock, shape: (8832, 43)
# Generated lag-1 for column task_stage, shape: (8832, 44)
# Generated lag-1 for column current_task, shape: (8832, 45)
# Generated lag-1 for column error_code, shape: (8832, 46)
# Generated lag-1 for column target_location, shape: (8832, 47)
# Generated lag-1 for column vesselVisitID, shape: (8832, 48)
# Generated lag-1 for column mission_type, shape: (8832, 49)
# Generated lag-1 for column  container1_type, shape: (8832, 50)
# Generated lag-1 for column container2_type, shape: (8832, 51)
# Generated lag-1 for column vehicle_mode, shape: (8832, 52)
# Generated lag-1 for column missionID , shape: (8832, 53)
# Generated lag-2 for column position_x, shape: (8832, 54)
# Generated lag-2 for column position_y, shape: (8832, 55)
# Generated lag-2 for column position_z, shape: (8832, 56)
# Generated lag-2 for column heading, shape: (8832, 57)
# Generated lag-2 for column speed, shape: (8832, 58)
# Generated lag-2 for column speed_command, shape: (8832, 59)
# Generated lag-2 for column mileage_distance, shape: (8832, 60)
# Generated lag-2 for column power_on_time, shape: (8832, 61)
# Generated lag-2 for column soc, shape: (8832, 62)
# Generated lag-2 for column fuel_level, shape: (8832, 63)
# Generated lag-2 for column chassis_mode, shape: (8832, 64)
# Generated lag-2 for column estop, shape: (8832, 65)
# Generated lag-2 for column charge_status, shape: (8832, 66)
# Generated lag-2 for column task_state_running, shape: (8832, 67)
# Generated lag-2 for column task_state_estop, shape: (8832, 68)
# Generated lag-2 for column task_state_lock, shape: (8832, 69)
# Generated lag-2 for column task_stage, shape: (8832, 70)
# Generated lag-2 for column current_task, shape: (8832, 71)
# Generated lag-2 for column error_code, shape: (8832, 72)
# Generated lag-2 for column target_location, shape: (8832, 73)
# Generated lag-2 for column vesselVisitID, shape: (8832, 74)
# Generated lag-2 for column mission_type, shape: (8832, 75)
# Generated lag-2 for column  container1_type, shape: (8832, 76)
# Generated lag-2 for column container2_type, shape: (8832, 77)
# Generated lag-2 for column vehicle_mode, shape: (8832, 78)
# Generated lag-2 for column missionID , shape: (8832, 79)
# Generated lag-3 for column position_x, shape: (8832, 80)
# Generated lag-3 for column position_y, shape: (8832, 81)
# Generated lag-3 for column position_z, shape: (8832, 82)
# Generated lag-3 for column heading, shape: (8832, 83)
# Generated lag-3 for column speed, shape: (8832, 84)
# Generated lag-3 for column speed_command, shape: (8832, 85)
# Generated lag-3 for column mileage_distance, shape: (8832, 86)
# Generated lag-3 for column power_on_time, shape: (8832, 87)
# Generated lag-3 for column soc, shape: (8832, 88)
# Generated lag-3 for column fuel_level, shape: (8832, 89)
# Generated lag-3 for column chassis_mode, shape: (8832, 90)
# Generated lag-3 for column estop, shape: (8832, 91)
# Generated lag-3 for column charge_status, shape: (8832, 92)
# Generated lag-3 for column task_state_running, shape: (8832, 93)
# Generated lag-3 for column task_state_estop, shape: (8832, 94)
# Generated lag-3 for column task_state_lock, shape: (8832, 95)
# Generated lag-3 for column task_stage, shape: (8832, 96)
# Generated lag-3 for column current_task, shape: (8832, 97)
# Generated lag-3 for column error_code, shape: (8832, 98)
# Generated lag-3 for column target_location, shape: (8832, 99)
# Generated lag-3 for column vesselVisitID, shape: (8832, 100)
# Generated lag-3 for column mission_type, shape: (8832, 101)
# Generated lag-3 for column  container1_type, shape: (8832, 102)
# Generated lag-3 for column container2_type, shape: (8832, 103)
# Generated lag-3 for column vehicle_mode, shape: (8832, 104)
# Generated lag-3 for column missionID , shape: (8832, 105)
# Generated lag-4 for column position_x, shape: (8832, 106)
# Generated lag-4 for column position_y, shape: (8832, 107)
# Generated lag-4 for column position_z, shape: (8832, 108)
# Generated lag-4 for column heading, shape: (8832, 109)
# Generated lag-4 for column speed, shape: (8832, 110)
# Generated lag-4 for column speed_command, shape: (8832, 111)
# Generated lag-4 for column mileage_distance, shape: (8832, 112)
# Generated lag-4 for column power_on_time, shape: (8832, 113)
# Generated lag-4 for column soc, shape: (8832, 114)
# Generated lag-4 for column fuel_level, shape: (8832, 115)
# Generated lag-4 for column chassis_mode, shape: (8832, 116)
# Generated lag-4 for column estop, shape: (8832, 117)
# Generated lag-4 for column charge_status, shape: (8832, 118)
# Generated lag-4 for column task_state_running, shape: (8832, 119)
# Generated lag-4 for column task_state_estop, shape: (8832, 120)
# Generated lag-4 for column task_state_lock, shape: (8832, 121)
# Generated lag-4 for column task_stage, shape: (8832, 122)
# Generated lag-4 for column current_task, shape: (8832, 123)
# Generated lag-4 for column error_code, shape: (8832, 124)
# Generated lag-4 for column target_location, shape: (8832, 125)
# Generated lag-4 for column vesselVisitID, shape: (8832, 126)
# Generated lag-4 for column mission_type, shape: (8832, 127)
# Generated lag-4 for column  container1_type, shape: (8832, 128)
# Generated lag-4 for column container2_type, shape: (8832, 129)
# Generated lag-4 for column vehicle_mode, shape: (8832, 130)
# Generated lag-4 for column missionID , shape: (8832, 131)
# Generated lag-5 for column position_x, shape: (8832, 132)
# Generated lag-5 for column position_y, shape: (8832, 133)
# Generated lag-5 for column position_z, shape: (8832, 134)
# Generated lag-5 for column heading, shape: (8832, 135)
# Generated lag-5 for column speed, shape: (8832, 136)
# Generated lag-5 for column speed_command, shape: (8832, 137)
# Generated lag-5 for column mileage_distance, shape: (8832, 138)
# Generated lag-5 for column power_on_time, shape: (8832, 139)
# Generated lag-5 for column soc, shape: (8832, 140)
# Generated lag-5 for column fuel_level, shape: (8832, 141)
# Generated lag-5 for column chassis_mode, shape: (8832, 142)
# Generated lag-5 for column estop, shape: (8832, 143)
# Generated lag-5 for column charge_status, shape: (8832, 144)
# Generated lag-5 for column task_state_running, shape: (8832, 145)
# Generated lag-5 for column task_state_estop, shape: (8832, 146)
# Generated lag-5 for column task_state_lock, shape: (8832, 147)
# Generated lag-5 for column task_stage, shape: (8832, 148)
# Generated lag-5 for column current_task, shape: (8832, 149)
# Generated lag-5 for column error_code, shape: (8832, 150)
# Generated lag-5 for column target_location, shape: (8832, 151)
# Generated lag-5 for column vesselVisitID, shape: (8832, 152)
# Generated lag-5 for column mission_type, shape: (8832, 153)
# Generated lag-5 for column  container1_type, shape: (8832, 154)
# Generated lag-5 for column container2_type, shape: (8832, 155)
# Generated lag-5 for column vehicle_mode, shape: (8832, 156)
# Generated lag-5 for column missionID , shape: (8832, 157)
# Generated lag-6 for column position_x, shape: (8832, 158)
# Generated lag-6 for column position_y, shape: (8832, 159)
# Generated lag-6 for column position_z, shape: (8832, 160)
# Generated lag-6 for column heading, shape: (8832, 161)
# Generated lag-6 for column speed, shape: (8832, 162)
# Generated lag-6 for column speed_command, shape: (8832, 163)
# Generated lag-6 for column mileage_distance, shape: (8832, 164)
# Generated lag-6 for column power_on_time, shape: (8832, 165)
# Generated lag-6 for column soc, shape: (8832, 166)
# Generated lag-6 for column fuel_level, shape: (8832, 167)
# Generated lag-6 for column chassis_mode, shape: (8832, 168)
# Generated lag-6 for column estop, shape: (8832, 169)
# Generated lag-6 for column charge_status, shape: (8832, 170)
# Generated lag-6 for column task_state_running, shape: (8832, 171)
# Generated lag-6 for column task_state_estop, shape: (8832, 172)
# Generated lag-6 for column task_state_lock, shape: (8832, 173)
# Generated lag-6 for column task_stage, shape: (8832, 174)
# Generated lag-6 for column current_task, shape: (8832, 175)
# Generated lag-6 for column error_code, shape: (8832, 176)
# Generated lag-6 for column target_location, shape: (8832, 177)
# Generated lag-6 for column vesselVisitID, shape: (8832, 178)
# Generated lag-6 for column mission_type, shape: (8832, 179)
# Generated lag-6 for column  container1_type, shape: (8832, 180)
# Generated lag-6 for column container2_type, shape: (8832, 181)
# Generated lag-6 for column vehicle_mode, shape: (8832, 182)
# Generated lag-6 for column missionID , shape: (8832, 183)
# Generated lag-7 for column position_x, shape: (8832, 184)
# Generated lag-7 for column position_y, shape: (8832, 185)
# Generated lag-7 for column position_z, shape: (8832, 186)
# Generated lag-7 for column heading, shape: (8832, 187)
# Generated lag-7 for column speed, shape: (8832, 188)
# Generated lag-7 for column speed_command, shape: (8832, 189)
# Generated lag-7 for column mileage_distance, shape: (8832, 190)
# Generated lag-7 for column power_on_time, shape: (8832, 191)
# Generated lag-7 for column soc, shape: (8832, 192)
# Generated lag-7 for column fuel_level, shape: (8832, 193)
# Generated lag-7 for column chassis_mode, shape: (8832, 194)
# Generated lag-7 for column estop, shape: (8832, 195)
# Generated lag-7 for column charge_status, shape: (8832, 196)
# Generated lag-7 for column task_state_running, shape: (8832, 197)
# Generated lag-7 for column task_state_estop, shape: (8832, 198)
# Generated lag-7 for column task_state_lock, shape: (8832, 199)
# Generated lag-7 for column task_stage, shape: (8832, 200)
# Generated lag-7 for column current_task, shape: (8832, 201)
# Generated lag-7 for column error_code, shape: (8832, 202)
# Generated lag-7 for column target_location, shape: (8832, 203)
# Generated lag-7 for column vesselVisitID, shape: (8832, 204)
# Generated lag-7 for column mission_type, shape: (8832, 205)
# Generated lag-7 for column  container1_type, shape: (8832, 206)
# Generated lag-7 for column container2_type, shape: (8832, 207)
# Generated lag-7 for column vehicle_mode, shape: (8832, 208)
# Generated lag-7 for column missionID , shape: (8832, 209)
# Generated lag-8 for column position_x, shape: (8832, 210)
# Generated lag-8 for column position_y, shape: (8832, 211)
# Generated lag-8 for column position_z, shape: (8832, 212)
# Generated lag-8 for column heading, shape: (8832, 213)
# Generated lag-8 for column speed, shape: (8832, 214)
# Generated lag-8 for column speed_command, shape: (8832, 215)
# Generated lag-8 for column mileage_distance, shape: (8832, 216)
# Generated lag-8 for column power_on_time, shape: (8832, 217)
# Generated lag-8 for column soc, shape: (8832, 218)
# Generated lag-8 for column fuel_level, shape: (8832, 219)
# Generated lag-8 for column chassis_mode, shape: (8832, 220)
# Generated lag-8 for column estop, shape: (8832, 221)
# Generated lag-8 for column charge_status, shape: (8832, 222)
# Generated lag-8 for column task_state_running, shape: (8832, 223)
# Generated lag-8 for column task_state_estop, shape: (8832, 224)
# Generated lag-8 for column task_state_lock, shape: (8832, 225)
# Generated lag-8 for column task_stage, shape: (8832, 226)
# Generated lag-8 for column current_task, shape: (8832, 227)
# Generated lag-8 for column error_code, shape: (8832, 228)
# Generated lag-8 for column target_location, shape: (8832, 229)
# Generated lag-8 for column vesselVisitID, shape: (8832, 230)
# Generated lag-8 for column mission_type, shape: (8832, 231)
# Generated lag-8 for column  container1_type, shape: (8832, 232)
# Generated lag-8 for column container2_type, shape: (8832, 233)
# Generated lag-8 for column vehicle_mode, shape: (8832, 234)
# Generated lag-8 for column missionID , shape: (8832, 235)
# Generated lag-9 for column position_x, shape: (8832, 236)
# Generated lag-9 for column position_y, shape: (8832, 237)
# Generated lag-9 for column position_z, shape: (8832, 238)
# Generated lag-9 for column heading, shape: (8832, 239)
# Generated lag-9 for column speed, shape: (8832, 240)
# Generated lag-9 for column speed_command, shape: (8832, 241)
# Generated lag-9 for column mileage_distance, shape: (8832, 242)
# Generated lag-9 for column power_on_time, shape: (8832, 243)
# Generated lag-9 for column soc, shape: (8832, 244)
# Generated lag-9 for column fuel_level, shape: (8832, 245)
# Generated lag-9 for column chassis_mode, shape: (8832, 246)
# Generated lag-9 for column estop, shape: (8832, 247)
# Generated lag-9 for column charge_status, shape: (8832, 248)
# Generated lag-9 for column task_state_running, shape: (8832, 249)
# Generated lag-9 for column task_state_estop, shape: (8832, 250)
# Generated lag-9 for column task_state_lock, shape: (8832, 251)
# Generated lag-9 for column task_stage, shape: (8832, 252)
# Generated lag-9 for column current_task, shape: (8832, 253)
# Generated lag-9 for column error_code, shape: (8832, 254)
# Generated lag-9 for column target_location, shape: (8832, 255)
# Generated lag-9 for column vesselVisitID, shape: (8832, 256)
# Generated lag-9 for column mission_type, shape: (8832, 257)
# Generated lag-9 for column  container1_type, shape: (8832, 258)
# Generated lag-9 for column container2_type, shape: (8832, 259)
# Generated lag-9 for column vehicle_mode, shape: (8832, 260)
# Generated lag-9 for column missionID , shape: (8832, 261)
# Generated lag-10 for column position_x, shape: (8832, 262)
# Generated lag-10 for column position_y, shape: (8832, 263)
# Generated lag-10 for column position_z, shape: (8832, 264)
# Generated lag-10 for column heading, shape: (8832, 265)
# Generated lag-10 for column speed, shape: (8832, 266)
# Generated lag-10 for column speed_command, shape: (8832, 267)
# Generated lag-10 for column mileage_distance, shape: (8832, 268)
# Generated lag-10 for column power_on_time, shape: (8832, 269)
# Generated lag-10 for column soc, shape: (8832, 270)
# Generated lag-10 for column fuel_level, shape: (8832, 271)
# Generated lag-10 for column chassis_mode, shape: (8832, 272)
# Generated lag-10 for column estop, shape: (8832, 273)
# Generated lag-10 for column charge_status, shape: (8832, 274)
# Generated lag-10 for column task_state_running, shape: (8832, 275)
# Generated lag-10 for column task_state_estop, shape: (8832, 276)
# Generated lag-10 for column task_state_lock, shape: (8832, 277)
# Generated lag-10 for column task_stage, shape: (8832, 278)
# Generated lag-10 for column current_task, shape: (8832, 279)
# Generated lag-10 for column error_code, shape: (8832, 280)
# Generated lag-10 for column target_location, shape: (8832, 281)
# Generated lag-10 for column vesselVisitID, shape: (8832, 282)
# Generated lag-10 for column mission_type, shape: (8832, 283)
# Generated lag-10 for column  container1_type, shape: (8832, 284)
# Generated lag-10 for column container2_type, shape: (8832, 285)
# Generated lag-10 for column vehicle_mode, shape: (8832, 286)
# Generated lag-10 for column missionID , shape: (8832, 287)
# Shape before removing first 10 rows: (8832, 287)
# Shape after removing first 10 rows: (8822, 287)
# Shape after concatenating all areas: (8822, 287)
# Final dataframe shape: (8822, 261)
# Processing area: 0.0, initial shape: (2207, 27)
# Generated lag-1 for column position_x, shape: (2207, 28)
# Generated lag-1 for column position_y, shape: (2207, 29)
# Generated lag-1 for column position_z, shape: (2207, 30)
# Generated lag-1 for column heading, shape: (2207, 31)
# Generated lag-1 for column speed, shape: (2207, 32)
# Generated lag-1 for column speed_command, shape: (2207, 33)
# Generated lag-1 for column mileage_distance, shape: (2207, 34)
# Generated lag-1 for column power_on_time, shape: (2207, 35)
# Generated lag-1 for column soc, shape: (2207, 36)
# Generated lag-1 for column fuel_level, shape: (2207, 37)
# Generated lag-1 for column chassis_mode, shape: (2207, 38)
# Generated lag-1 for column estop, shape: (2207, 39)
# Generated lag-1 for column charge_status, shape: (2207, 40)
# Generated lag-1 for column task_state_running, shape: (2207, 41)
# Generated lag-1 for column task_state_estop, shape: (2207, 42)
# Generated lag-1 for column task_state_lock, shape: (2207, 43)
# Generated lag-1 for column task_stage, shape: (2207, 44)
# Generated lag-1 for column current_task, shape: (2207, 45)
# Generated lag-1 for column error_code, shape: (2207, 46)
# Generated lag-1 for column target_location, shape: (2207, 47)
# Generated lag-1 for column vesselVisitID, shape: (2207, 48)
# Generated lag-1 for column mission_type, shape: (2207, 49)
# Generated lag-1 for column  container1_type, shape: (2207, 50)
# Generated lag-1 for column container2_type, shape: (2207, 51)
# Generated lag-1 for column vehicle_mode, shape: (2207, 52)
# Generated lag-1 for column missionID , shape: (2207, 53)
# Generated lag-2 for column position_x, shape: (2207, 54)
# Generated lag-2 for column position_y, shape: (2207, 55)
# Generated lag-2 for column position_z, shape: (2207, 56)
# Generated lag-2 for column heading, shape: (2207, 57)
# Generated lag-2 for column speed, shape: (2207, 58)
# Generated lag-2 for column speed_command, shape: (2207, 59)
# Generated lag-2 for column mileage_distance, shape: (2207, 60)
# Generated lag-2 for column power_on_time, shape: (2207, 61)
# Generated lag-2 for column soc, shape: (2207, 62)
# Generated lag-2 for column fuel_level, shape: (2207, 63)
# Generated lag-2 for column chassis_mode, shape: (2207, 64)
# Generated lag-2 for column estop, shape: (2207, 65)
# Generated lag-2 for column charge_status, shape: (2207, 66)
# Generated lag-2 for column task_state_running, shape: (2207, 67)
# Generated lag-2 for column task_state_estop, shape: (2207, 68)
# Generated lag-2 for column task_state_lock, shape: (2207, 69)
# Generated lag-2 for column task_stage, shape: (2207, 70)
# Generated lag-2 for column current_task, shape: (2207, 71)
# Generated lag-2 for column error_code, shape: (2207, 72)
# Generated lag-2 for column target_location, shape: (2207, 73)
# Generated lag-2 for column vesselVisitID, shape: (2207, 74)
# Generated lag-2 for column mission_type, shape: (2207, 75)
# Generated lag-2 for column  container1_type, shape: (2207, 76)
# Generated lag-2 for column container2_type, shape: (2207, 77)
# Generated lag-2 for column vehicle_mode, shape: (2207, 78)
# Generated lag-2 for column missionID , shape: (2207, 79)
# Generated lag-3 for column position_x, shape: (2207, 80)
# Generated lag-3 for column position_y, shape: (2207, 81)
# Generated lag-3 for column position_z, shape: (2207, 82)
# Generated lag-3 for column heading, shape: (2207, 83)
# Generated lag-3 for column speed, shape: (2207, 84)
# Generated lag-3 for column speed_command, shape: (2207, 85)
# Generated lag-3 for column mileage_distance, shape: (2207, 86)
# Generated lag-3 for column power_on_time, shape: (2207, 87)
# Generated lag-3 for column soc, shape: (2207, 88)
# Generated lag-3 for column fuel_level, shape: (2207, 89)
# Generated lag-3 for column chassis_mode, shape: (2207, 90)
# Generated lag-3 for column estop, shape: (2207, 91)
# Generated lag-3 for column charge_status, shape: (2207, 92)
# Generated lag-3 for column task_state_running, shape: (2207, 93)
# Generated lag-3 for column task_state_estop, shape: (2207, 94)
# Generated lag-3 for column task_state_lock, shape: (2207, 95)
# Generated lag-3 for column task_stage, shape: (2207, 96)
# Generated lag-3 for column current_task, shape: (2207, 97)
# Generated lag-3 for column error_code, shape: (2207, 98)
# Generated lag-3 for column target_location, shape: (2207, 99)
# Generated lag-3 for column vesselVisitID, shape: (2207, 100)
# Generated lag-3 for column mission_type, shape: (2207, 101)
# Generated lag-3 for column  container1_type, shape: (2207, 102)
# Generated lag-3 for column container2_type, shape: (2207, 103)
# Generated lag-3 for column vehicle_mode, shape: (2207, 104)
# Generated lag-3 for column missionID , shape: (2207, 105)
# Generated lag-4 for column position_x, shape: (2207, 106)
# Generated lag-4 for column position_y, shape: (2207, 107)
# Generated lag-4 for column position_z, shape: (2207, 108)
# Generated lag-4 for column heading, shape: (2207, 109)
# Generated lag-4 for column speed, shape: (2207, 110)
# Generated lag-4 for column speed_command, shape: (2207, 111)
# Generated lag-4 for column mileage_distance, shape: (2207, 112)
# Generated lag-4 for column power_on_time, shape: (2207, 113)
# Generated lag-4 for column soc, shape: (2207, 114)
# Generated lag-4 for column fuel_level, shape: (2207, 115)
# Generated lag-4 for column chassis_mode, shape: (2207, 116)
# Generated lag-4 for column estop, shape: (2207, 117)
# Generated lag-4 for column charge_status, shape: (2207, 118)
# Generated lag-4 for column task_state_running, shape: (2207, 119)
# Generated lag-4 for column task_state_estop, shape: (2207, 120)
# Generated lag-4 for column task_state_lock, shape: (2207, 121)
# Generated lag-4 for column task_stage, shape: (2207, 122)
# Generated lag-4 for column current_task, shape: (2207, 123)
# Generated lag-4 for column error_code, shape: (2207, 124)
# Generated lag-4 for column target_location, shape: (2207, 125)
# Generated lag-4 for column vesselVisitID, shape: (2207, 126)
# Generated lag-4 for column mission_type, shape: (2207, 127)
# Generated lag-4 for column  container1_type, shape: (2207, 128)
# Generated lag-4 for column container2_type, shape: (2207, 129)
# Generated lag-4 for column vehicle_mode, shape: (2207, 130)
# Generated lag-4 for column missionID , shape: (2207, 131)
# Generated lag-5 for column position_x, shape: (2207, 132)
# Generated lag-5 for column position_y, shape: (2207, 133)
# Generated lag-5 for column position_z, shape: (2207, 134)
# Generated lag-5 for column heading, shape: (2207, 135)
# Generated lag-5 for column speed, shape: (2207, 136)
# Generated lag-5 for column speed_command, shape: (2207, 137)
# Generated lag-5 for column mileage_distance, shape: (2207, 138)
# Generated lag-5 for column power_on_time, shape: (2207, 139)
# Generated lag-5 for column soc, shape: (2207, 140)
# Generated lag-5 for column fuel_level, shape: (2207, 141)
# Generated lag-5 for column chassis_mode, shape: (2207, 142)
# Generated lag-5 for column estop, shape: (2207, 143)
# Generated lag-5 for column charge_status, shape: (2207, 144)
# Generated lag-5 for column task_state_running, shape: (2207, 145)
# Generated lag-5 for column task_state_estop, shape: (2207, 146)
# Generated lag-5 for column task_state_lock, shape: (2207, 147)
# Generated lag-5 for column task_stage, shape: (2207, 148)
# Generated lag-5 for column current_task, shape: (2207, 149)
# Generated lag-5 for column error_code, shape: (2207, 150)
# Generated lag-5 for column target_location, shape: (2207, 151)
# Generated lag-5 for column vesselVisitID, shape: (2207, 152)
# Generated lag-5 for column mission_type, shape: (2207, 153)
# Generated lag-5 for column  container1_type, shape: (2207, 154)
# Generated lag-5 for column container2_type, shape: (2207, 155)
# Generated lag-5 for column vehicle_mode, shape: (2207, 156)
# Generated lag-5 for column missionID , shape: (2207, 157)
# Generated lag-6 for column position_x, shape: (2207, 158)
# Generated lag-6 for column position_y, shape: (2207, 159)
# Generated lag-6 for column position_z, shape: (2207, 160)
# Generated lag-6 for column heading, shape: (2207, 161)
# Generated lag-6 for column speed, shape: (2207, 162)
# Generated lag-6 for column speed_command, shape: (2207, 163)
# Generated lag-6 for column mileage_distance, shape: (2207, 164)
# Generated lag-6 for column power_on_time, shape: (2207, 165)
# Generated lag-6 for column soc, shape: (2207, 166)
# Generated lag-6 for column fuel_level, shape: (2207, 167)
# Generated lag-6 for column chassis_mode, shape: (2207, 168)
# Generated lag-6 for column estop, shape: (2207, 169)
# Generated lag-6 for column charge_status, shape: (2207, 170)
# Generated lag-6 for column task_state_running, shape: (2207, 171)
# Generated lag-6 for column task_state_estop, shape: (2207, 172)
# Generated lag-6 for column task_state_lock, shape: (2207, 173)
# Generated lag-6 for column task_stage, shape: (2207, 174)
# Generated lag-6 for column current_task, shape: (2207, 175)
# Generated lag-6 for column error_code, shape: (2207, 176)
# Generated lag-6 for column target_location, shape: (2207, 177)
# Generated lag-6 for column vesselVisitID, shape: (2207, 178)
# Generated lag-6 for column mission_type, shape: (2207, 179)
# Generated lag-6 for column  container1_type, shape: (2207, 180)
# Generated lag-6 for column container2_type, shape: (2207, 181)
# Generated lag-6 for column vehicle_mode, shape: (2207, 182)
# Generated lag-6 for column missionID , shape: (2207, 183)
# Generated lag-7 for column position_x, shape: (2207, 184)
# Generated lag-7 for column position_y, shape: (2207, 185)
# Generated lag-7 for column position_z, shape: (2207, 186)
# Generated lag-7 for column heading, shape: (2207, 187)
# Generated lag-7 for column speed, shape: (2207, 188)
# Generated lag-7 for column speed_command, shape: (2207, 189)
# Generated lag-7 for column mileage_distance, shape: (2207, 190)
# Generated lag-7 for column power_on_time, shape: (2207, 191)
# Generated lag-7 for column soc, shape: (2207, 192)
# Generated lag-7 for column fuel_level, shape: (2207, 193)
# Generated lag-7 for column chassis_mode, shape: (2207, 194)
# Generated lag-7 for column estop, shape: (2207, 195)
# Generated lag-7 for column charge_status, shape: (2207, 196)
# Generated lag-7 for column task_state_running, shape: (2207, 197)
# Generated lag-7 for column task_state_estop, shape: (2207, 198)
# Generated lag-7 for column task_state_lock, shape: (2207, 199)
# Generated lag-7 for column task_stage, shape: (2207, 200)
# Generated lag-7 for column current_task, shape: (2207, 201)
# Generated lag-7 for column error_code, shape: (2207, 202)
# Generated lag-7 for column target_location, shape: (2207, 203)
# Generated lag-7 for column vesselVisitID, shape: (2207, 204)
# Generated lag-7 for column mission_type, shape: (2207, 205)
# Generated lag-7 for column  container1_type, shape: (2207, 206)
# Generated lag-7 for column container2_type, shape: (2207, 207)
# Generated lag-7 for column vehicle_mode, shape: (2207, 208)
# Generated lag-7 for column missionID , shape: (2207, 209)
# Generated lag-8 for column position_x, shape: (2207, 210)
# Generated lag-8 for column position_y, shape: (2207, 211)
# Generated lag-8 for column position_z, shape: (2207, 212)
# Generated lag-8 for column heading, shape: (2207, 213)
# Generated lag-8 for column speed, shape: (2207, 214)
# Generated lag-8 for column speed_command, shape: (2207, 215)
# Generated lag-8 for column mileage_distance, shape: (2207, 216)
# Generated lag-8 for column power_on_time, shape: (2207, 217)
# Generated lag-8 for column soc, shape: (2207, 218)
# Generated lag-8 for column fuel_level, shape: (2207, 219)
# Generated lag-8 for column chassis_mode, shape: (2207, 220)
# Generated lag-8 for column estop, shape: (2207, 221)
# Generated lag-8 for column charge_status, shape: (2207, 222)
# Generated lag-8 for column task_state_running, shape: (2207, 223)
# Generated lag-8 for column task_state_estop, shape: (2207, 224)
# Generated lag-8 for column task_state_lock, shape: (2207, 225)
# Generated lag-8 for column task_stage, shape: (2207, 226)
# Generated lag-8 for column current_task, shape: (2207, 227)
# Generated lag-8 for column error_code, shape: (2207, 228)
# Generated lag-8 for column target_location, shape: (2207, 229)
# Generated lag-8 for column vesselVisitID, shape: (2207, 230)
# Generated lag-8 for column mission_type, shape: (2207, 231)
# Generated lag-8 for column  container1_type, shape: (2207, 232)
# Generated lag-8 for column container2_type, shape: (2207, 233)
# Generated lag-8 for column vehicle_mode, shape: (2207, 234)
# Generated lag-8 for column missionID , shape: (2207, 235)
# Generated lag-9 for column position_x, shape: (2207, 236)
# Generated lag-9 for column position_y, shape: (2207, 237)
# Generated lag-9 for column position_z, shape: (2207, 238)
# Generated lag-9 for column heading, shape: (2207, 239)
# Generated lag-9 for column speed, shape: (2207, 240)
# Generated lag-9 for column speed_command, shape: (2207, 241)
# Generated lag-9 for column mileage_distance, shape: (2207, 242)
# Generated lag-9 for column power_on_time, shape: (2207, 243)
# Generated lag-9 for column soc, shape: (2207, 244)
# Generated lag-9 for column fuel_level, shape: (2207, 245)
# Generated lag-9 for column chassis_mode, shape: (2207, 246)
# Generated lag-9 for column estop, shape: (2207, 247)
# Generated lag-9 for column charge_status, shape: (2207, 248)
# Generated lag-9 for column task_state_running, shape: (2207, 249)
# Generated lag-9 for column task_state_estop, shape: (2207, 250)
# Generated lag-9 for column task_state_lock, shape: (2207, 251)
# Generated lag-9 for column task_stage, shape: (2207, 252)
# Generated lag-9 for column current_task, shape: (2207, 253)
# Generated lag-9 for column error_code, shape: (2207, 254)
# Generated lag-9 for column target_location, shape: (2207, 255)
# Generated lag-9 for column vesselVisitID, shape: (2207, 256)
# Generated lag-9 for column mission_type, shape: (2207, 257)
# Generated lag-9 for column  container1_type, shape: (2207, 258)
# Generated lag-9 for column container2_type, shape: (2207, 259)
# Generated lag-9 for column vehicle_mode, shape: (2207, 260)
# Generated lag-9 for column missionID , shape: (2207, 261)
# Generated lag-10 for column position_x, shape: (2207, 262)
# Generated lag-10 for column position_y, shape: (2207, 263)
# Generated lag-10 for column position_z, shape: (2207, 264)
# Generated lag-10 for column heading, shape: (2207, 265)
# Generated lag-10 for column speed, shape: (2207, 266)
# Generated lag-10 for column speed_command, shape: (2207, 267)
# Generated lag-10 for column mileage_distance, shape: (2207, 268)
# Generated lag-10 for column power_on_time, shape: (2207, 269)
# Generated lag-10 for column soc, shape: (2207, 270)
# Generated lag-10 for column fuel_level, shape: (2207, 271)
# Generated lag-10 for column chassis_mode, shape: (2207, 272)
# Generated lag-10 for column estop, shape: (2207, 273)
# Generated lag-10 for column charge_status, shape: (2207, 274)
# Generated lag-10 for column task_state_running, shape: (2207, 275)
# Generated lag-10 for column task_state_estop, shape: (2207, 276)
# Generated lag-10 for column task_state_lock, shape: (2207, 277)
# Generated lag-10 for column task_stage, shape: (2207, 278)
# Generated lag-10 for column current_task, shape: (2207, 279)
# Generated lag-10 for column error_code, shape: (2207, 280)
# Generated lag-10 for column target_location, shape: (2207, 281)
# Generated lag-10 for column vesselVisitID, shape: (2207, 282)
# Generated lag-10 for column mission_type, shape: (2207, 283)
# Generated lag-10 for column  container1_type, shape: (2207, 284)
# Generated lag-10 for column container2_type, shape: (2207, 285)
# Generated lag-10 for column vehicle_mode, shape: (2207, 286)
# Generated lag-10 for column missionID , shape: (2207, 287)
# Shape before removing first 10 rows: (2207, 287)
# Shape after removing first 10 rows: (2197, 287)
# Shape after concatenating all areas: (2197, 287)
# Final dataframe shape: (2197, 261)
# Processing area: 0.0, initial shape: (8832, 2)
# Generated lag-1 for column charge_status, shape: (8832, 3)
# Generated lag-2 for column charge_status, shape: (8832, 4)
# Generated lag-3 for column charge_status, shape: (8832, 5)
# Generated lag-4 for column charge_status, shape: (8832, 6)
# Generated lag-5 for column charge_status, shape: (8832, 7)
# Generated lag-6 for column charge_status, shape: (8832, 8)
# Generated lag-7 for column charge_status, shape: (8832, 9)
# Generated lag-8 for column charge_status, shape: (8832, 10)
# Generated lag-9 for column charge_status, shape: (8832, 11)
# Generated lag-10 for column charge_status, shape: (8832, 12)
# Shape before removing first 10 rows: (8832, 12)
# Shape after removing first 10 rows: (8822, 12)
# Shape after concatenating all areas: (8822, 12)
# Final dataframe shape: (8822, 2)
# Processing area: 0.0, initial shape: (2207, 2)
# Generated lag-1 for column charge_status, shape: (2207, 3)
# Generated lag-2 for column charge_status, shape: (2207, 4)
# Generated lag-3 for column charge_status, shape: (2207, 5)
# Generated lag-4 for column charge_status, shape: (2207, 6)
# Generated lag-5 for column charge_status, shape: (2207, 7)
# Generated lag-6 for column charge_status, shape: (2207, 8)
# Generated lag-7 for column charge_status, shape: (2207, 9)
# Generated lag-8 for column charge_status, shape: (2207, 10)
# Generated lag-9 for column charge_status, shape: (2207, 11)
# Generated lag-10 for column charge_status, shape: (2207, 12)
# Shape before removing first 10 rows: (2207, 12)
# Shape after removing first 10 rows: (2197, 12)
# Shape after concatenating all areas: (2197, 12)
# Final dataframe shape: (2197, 2)
# 生成时间滞后后 X_train 形状: (8822, 261)
# 生成时间滞后后 X_val 形状: (2197, 261)
# 生成时间滞后后 y_train 形状: (8822, 2)
# 生成时间滞后后 y_val 形状: (2197, 2)
# 日期时间特征训练集: None
# 日期时间特征验证集: None
# 统计数据训练集: None
# 统计数据验证集: None

# %%
X_train.head()
# Out:
#                                missionID _lag-10  vehicle_mode_lag-10  \
# local_time
# 1970-01-01 00:00:00.000000010           0.944444                  1.0
# 1970-01-01 00:00:00.000000011           0.944444                  1.0
# 1970-01-01 00:00:00.000000012           0.944444                  1.0
# 1970-01-01 00:00:00.000000013           0.944444                  1.0
# 1970-01-01 00:00:00.000000014           0.944444                  1.0
#
#                                container2_type_lag-10  \
# local_time
# 1970-01-01 00:00:00.000000010                     0.0
# 1970-01-01 00:00:00.000000011                     0.0
# 1970-01-01 00:00:00.000000012                     0.0
# 1970-01-01 00:00:00.000000013                     0.0
# 1970-01-01 00:00:00.000000014                     0.0
#
#                                 container1_type_lag-10  mission_type_lag-10  \
# local_time
# 1970-01-01 00:00:00.000000010                      0.0             0.666667
# 1970-01-01 00:00:00.000000011                      0.0             0.666667
# 1970-01-01 00:00:00.000000012                      0.0             0.666667
# 1970-01-01 00:00:00.000000013                      0.0             0.666667
# 1970-01-01 00:00:00.000000014                      0.0             0.666667
#
#                                vesselVisitID_lag-10  target_location_lag-10  \
# local_time
# 1970-01-01 00:00:00.000000010                   0.0                    0.25
# 1970-01-01 00:00:00.000000011                   0.0                    0.25
# 1970-01-01 00:00:00.000000012                   0.0                    0.25
# 1970-01-01 00:00:00.000000013                   0.0                    0.25
# 1970-01-01 00:00:00.000000014                   0.0                    0.25
#
#                                error_code_lag-10  current_task_lag-10  \
# local_time
# 1970-01-01 00:00:00.000000010                0.0                 0.75
# 1970-01-01 00:00:00.000000011                0.0                 0.75
# 1970-01-01 00:00:00.000000012                0.0                 0.75
# 1970-01-01 00:00:00.000000013                0.0                 0.75
# 1970-01-01 00:00:00.000000014                0.0                 0.75
#
#                                task_stage_lag-10  ...  soc_lag-1  \
# local_time                                        ...
# 1970-01-01 00:00:00.000000010           0.333333  ...   0.338462
# 1970-01-01 00:00:00.000000011           0.333333  ...   0.338462
# 1970-01-01 00:00:00.000000012           0.333333  ...   0.338462
# 1970-01-01 00:00:00.000000013           0.333333  ...   0.338462
# 1970-01-01 00:00:00.000000014           0.333333  ...   0.338462
#
#                                power_on_time_lag-1  mileage_distance_lag-1  \
# local_time
# 1970-01-01 00:00:00.000000010             0.000977                     0.0
# 1970-01-01 00:00:00.000000011             0.001099                     0.0
# 1970-01-01 00:00:00.000000012             0.001221                     0.0
# 1970-01-01 00:00:00.000000013             0.001221                     0.0
# 1970-01-01 00:00:00.000000014             0.001465                     0.0
#
#                                speed_command_lag-1  speed_lag-1  \
# local_time
# 1970-01-01 00:00:00.000000010             0.032353     0.024842
# 1970-01-01 00:00:00.000000011             0.032353     0.024842
# 1970-01-01 00:00:00.000000012             0.032353     0.024842
# 1970-01-01 00:00:00.000000013             0.032353     0.024842
# 1970-01-01 00:00:00.000000014             0.032353     0.024842
#
#                                heading_lag-1  position_z_lag-1  \
# local_time
# 1970-01-01 00:00:00.000000010       0.499589               0.0
# 1970-01-01 00:00:00.000000011       0.499592               0.0
# 1970-01-01 00:00:00.000000012       0.499581               0.0
# 1970-01-01 00:00:00.000000013       0.499571               0.0
# 1970-01-01 00:00:00.000000014       0.499575               0.0
#
#                                position_y_lag-1  position_x_lag-1  vehicle_id
# local_time
# 1970-01-01 00:00:00.000000010          0.838228          0.287738         0.0
# 1970-01-01 00:00:00.000000011          0.838228          0.287738         0.0
# 1970-01-01 00:00:00.000000012          0.838227          0.287738         0.0
# 1970-01-01 00:00:00.000000013          0.838224          0.287737         0.0
# 1970-01-01 00:00:00.000000014          0.838217          0.287731         0.0
#
# [5 rows x 261 columns]

# %%
y_train.head()
# Out:
#                                charge_status  vehicle_id
# local_time
# 1970-01-01 00:00:00.000000010            0.0         0.0
# 1970-01-01 00:00:00.000000011            0.0         0.0
# 1970-01-01 00:00:00.000000012            0.0         0.0
# 1970-01-01 00:00:00.000000013            0.0         0.0
# 1970-01-01 00:00:00.000000014            0.0         0.0

# %%
x_scaler, y_scaler
# Out:
# (MinMaxScaler(), MinMaxScaler())

# %% [markdown]
# ### Postprocessing Stage
#
# In this stage we transform data in a way that can be fed into ML algorithms.

# %%
def make_postprocessing(X_train, X_val, y_train, y_val, exogenous_data_train, exogenous_data_val, x_scaler, y_scaler):
    """将数据处理为可供机器学习算法使用的格式"""

    # 如果指定的区域多于一个，按区域获取数据；单个小车在这里不执行
    if X_train[args.identifier].nunique() != 1:
        print("按区域获取数据...")
        area_X_train, area_X_val, area_y_train, area_y_val = get_data_by_area(X_train, X_val,
                                                                              y_train, y_val, 
                                                                              identifier=args.identifier)
        print(f"区域训练集数据: {area_X_train}")
        print(f"区域验证集数据: {area_X_val}")
    else:
        area_X_train, area_X_val, area_y_train, area_y_val = None, None, None, None

    # 按区域获取外生数据 单个小车在这里不执行
    if exogenous_data_train is not None:
        print("按区域获取外生数据...")
        exogenous_data_train, exogenous_data_val = get_exogenous_data_by_area(exogenous_data_train,
                                                                              exogenous_data_val)
        print(f"外生数据训练集: {exogenous_data_train}")
        print(f"外生数据验证集: {exogenous_data_val}")
        

    # 将数据转换为 numpy 数组，没有区域数据不执行
    if area_X_train is not None:
        for area in area_X_train:
            print(f"将区域 {area} 的数据转换为 numpy 数组...")
            tmp_X_train, tmp_y_train, tmp_X_val, tmp_y_val = remove_identifiers(
                area_X_train[area], area_y_train[area], area_X_val[area], area_y_val[area])
            tmp_X_train, tmp_y_train = tmp_X_train.to_numpy(), tmp_y_train.to_numpy()
            tmp_X_val, tmp_y_val = tmp_X_val.to_numpy(), tmp_y_val.to_numpy()
            area_X_train[area] = tmp_X_train
            area_X_val[area] = tmp_X_val
            area_y_train[area] = tmp_y_train
            area_y_val[area] = tmp_y_val
    # 没有外源数据不执行
    if exogenous_data_train is not None:
        for area in exogenous_data_train:
            print(f"将外生数据区域 {area} 转换为 numpy 数组...")
            exogenous_data_train[area] = exogenous_data_train[area].to_numpy()
            exogenous_data_val[area] = exogenous_data_val[area].to_numpy()

    # 从特征和目标变量中移除标识符
    print("移除标识符...")
    X_train, y_train, X_val, y_val = remove_identifiers(X_train, y_train, X_val, y_val)
    # 标签与特征数量对比，如果不对的话，抛出异常
    assert len(X_train.columns) == len(X_val.columns)
    # 计算每个时间步长的特征数量
    print("计算每个时间步长的特征数量...", len(X_train.columns),args.num_lags)
    num_features = len(X_train.columns) // args.num_lags
    print(f"每个时间步长的特征数量: {num_features}")
   
    # 转换为时间序列表示
    print("将数据转换为时间序列表示...")
    X_train = to_timeseries_rep(X_train.to_numpy(), num_lags=args.num_lags,
                                num_features=num_features)
    X_val = to_timeseries_rep(X_val.to_numpy(), num_lags=args.num_lags,
                              num_features=num_features)

    if area_X_train is not None:
        print("将区域数据转换为时间序列表示...")
        area_X_train = {area: to_timeseries_rep(area_X_train[area], num_lags=args.num_lags,
                                                num_features=num_features) for area in area_X_train}
        area_X_val = {area: to_timeseries_rep(area_X_val[area], num_lags=args.num_lags,
                                              num_features=num_features) for area in area_X_val}

    # 将目标变量转换为 numpy 数组
    print("将目标变量转换为 numpy 数组...")
    y_train, y_val = y_train.to_numpy(), y_val.to_numpy()
    print(f"y_train 形状: {y_train.shape}")
    print(f"y_val 形状: {y_val.shape}")

    # 中心化（所有）学习特定处理，这里也不会执行
    if not args.filter_bs and exogenous_data_train is not None:
        print("处理中心化学习的外生数据...")
        exogenous_data_train_combined, exogenous_data_val_combined = [], []
        for area in exogenous_data_train:
            exogenous_data_train_combined.extend(exogenous_data_train[area])
            exogenous_data_val_combined.extend(exogenous_data_val[area])
        exogenous_data_train_combined = np.stack(exogenous_data_train_combined)
        exogenous_data_val_combined = np.stack(exogenous_data_val_combined)
        exogenous_data_train["all"] = exogenous_data_train_combined
        exogenous_data_val["all"] = exogenous_data_val_combined
 


    return X_train, X_val, y_train, y_val, area_X_train, area_X_val, area_y_train, area_y_val, exogenous_data_train, exogenous_data_val

# %%
X_train, X_val, y_train, y_val, area_X_train, area_X_val, area_y_train, area_y_val, exogenous_data_train, exogenous_data_val = make_postprocessing(X_train, X_val, y_train, y_val, exogenous_data_train, exogenous_data_val, x_scaler, y_scaler)
# Out:
# 移除标识符...
# 计算每个时间步长的特征数量... 260 10
# 每个时间步长的特征数量: 26
# 将数据转换为时间序列表示...
# x的类型是：<class 'numpy.ndarray'>
# x的部分值是：[[0.94444448 1.         0.         ... 0.         0.83822787 0.2877382 ]
#  [0.94444448 1.         0.         ... 0.         0.83822805 0.2877382 ]
#  [0.94444448 1.         0.         ... 0.         0.83822727 0.2877382 ]
#  [0.94444448 1.         0.         ... 0.         0.83822405 0.28773665]
#  [0.94444448 1.         0.         ... 0.         0.83821714 0.28773081]]
# x的类型是：<class 'numpy.ndarray'>
# x的部分值是：[[0.12962963 1.         0.         ... 0.         0.92972988 0.98730958]
#  [0.12962963 1.         0.         ... 0.         0.92973363 0.98731631]
#  [0.12962963 1.         0.         ... 0.         0.92973733 0.98731387]
#  [0.12962963 1.         0.         ... 0.         0.9297303  0.98731786]
#  [0.12962963 1.         0.         ... 0.         0.92972732 0.98731452]]
# 将目标变量转换为 numpy 数组...
# y_train 形状: (8822, 1)
# y_val 形状: (2197, 1)

# %%
X_train[:2]
# Out:
# array([[[[9.44444478e-01],
#          [1.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [6.66666627e-01],
#          [0.00000000e+00],
#          [2.50000000e-01],
#          [0.00000000e+00],
#          [7.50000000e-01],
#          [3.33333343e-01],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [3.38461548e-01],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [3.23531739e-02],
#          [2.48420089e-02],
#          [4.99532372e-01],
#          [0.00000000e+00],
#          [8.38214278e-01],
#          [2.87736416e-01]],
#
#         [[9.44444478e-01],
#          [1.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [6.66666627e-01],
#          [0.00000000e+00],
#          [2.50000000e-01],
#          [0.00000000e+00],
#          [7.50000000e-01],
#          [3.33333343e-01],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [3.38461548e-01],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [3.23531739e-02],
#          [2.48420089e-02],
#          [4.99553621e-01],
#          [0.00000000e+00],
#          [8.38224411e-01],
#          [2.87735105e-01]],
#
#         [[9.44444478e-01],
#          [1.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [6.66666627e-01],
#          [0.00000000e+00],
#          [2.50000000e-01],
#          [0.00000000e+00],
#          [7.50000000e-01],
#          [3.33333343e-01],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [3.38461548e-01],
#          [2.44140625e-04],
#          [0.00000000e+00],
#          [3.23531739e-02],
#          [2.48420089e-02],
#          [4.99555945e-01],
#          [0.00000000e+00],
#          [8.38226676e-01],
#          [2.87726045e-01]],
#
#         [[9.44444478e-01],
#          [1.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [6.66666627e-01],
#          [0.00000000e+00],
#          [2.50000000e-01],
#          [0.00000000e+00],
#          [7.50000000e-01],
#          [3.33333343e-01],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [3.38461548e-01],
#          [2.44140625e-04],
#          [0.00000000e+00],
#          [3.23531739e-02],
#          [2.48420089e-02],
#          [4.99573082e-01],
#          [0.00000000e+00],
#          [8.38231325e-01],
#          [2.87728310e-01]],
#
#         [[9.44444478e-01],
#          [1.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [6.66666627e-01],
#          [0.00000000e+00],
#          [2.50000000e-01],
#          [0.00000000e+00],
#          [7.50000000e-01],
#          [3.33333343e-01],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [3.38461548e-01],
#          [4.88281250e-04],
#          [0.00000000e+00],
#          [3.23531739e-02],
#          [2.48420089e-02],
#          [4.99571800e-01],
#          [0.00000000e+00],
#          [8.38233948e-01],
#          [2.87729859e-01]],
#
#         [[9.44444478e-01],
#          [1.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [6.66666627e-01],
#          [0.00000000e+00],
#          [2.50000000e-01],
#          [0.00000000e+00],
#          [7.50000000e-01],
#          [3.33333343e-01],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [3.38461548e-01],
#          [6.10351562e-04],
#          [0.00000000e+00],
#          [3.23531739e-02],
#          [2.48420089e-02],
#          [4.99581546e-01],
#          [0.00000000e+00],
#          [8.38234663e-01],
#          [2.87736535e-01]],
#
#         [[9.44444478e-01],
#          [1.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [6.66666627e-01],
#          [0.00000000e+00],
#          [2.50000000e-01],
#          [0.00000000e+00],
#          [7.50000000e-01],
#          [3.33333343e-01],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [3.38461548e-01],
#          [6.10351562e-04],
#          [0.00000000e+00],
#          [3.23531739e-02],
#          [2.48420089e-02],
#          [4.99584049e-01],
#          [0.00000000e+00],
#          [8.38235974e-01],
#          [2.87737966e-01]],
#
#         [[9.44444478e-01],
#          [1.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [6.66666627e-01],
#          [0.00000000e+00],
#          [2.50000000e-01],
#          [0.00000000e+00],
#          [7.50000000e-01],
#          [3.33333343e-01],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [3.38461548e-01],
#          [7.32421875e-04],
#          [0.00000000e+00],
#          [3.23531739e-02],
#          [2.48420089e-02],
#          [4.99584168e-01],
#          [0.00000000e+00],
#          [8.38235557e-01],
#          [2.87736654e-01]],
#
#         [[9.44444478e-01],
#          [1.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [6.66666627e-01],
#          [0.00000000e+00],
#          [2.50000000e-01],
#          [0.00000000e+00],
#          [7.50000000e-01],
#          [3.33333343e-01],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [3.38461548e-01],
#          [8.54492188e-04],
#          [0.00000000e+00],
#          [3.23531739e-02],
#          [2.48420089e-02],
#          [4.99588042e-01],
#          [0.00000000e+00],
#          [8.38234425e-01],
#          [2.87733912e-01]],
#
#         [[9.44444478e-01],
#          [1.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [6.66666627e-01],
#          [0.00000000e+00],
#          [2.50000000e-01],
#          [0.00000000e+00],
#          [7.50000000e-01],
#          [3.33333343e-01],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [3.38461548e-01],
#          [9.76562500e-04],
#          [0.00000000e+00],
#          [3.23531739e-02],
#          [2.48420089e-02],
#          [4.99588966e-01],
#          [0.00000000e+00],
#          [8.38227868e-01],
#          [2.87738204e-01]]],
#
#
#        [[[9.44444478e-01],
#          [1.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [6.66666627e-01],
#          [0.00000000e+00],
#          [2.50000000e-01],
#          [0.00000000e+00],
#          [7.50000000e-01],
#          [3.33333343e-01],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [3.38461548e-01],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [3.23531739e-02],
#          [2.48420089e-02],
#          [4.99553621e-01],
#          [0.00000000e+00],
#          [8.38224411e-01],
#          [2.87735105e-01]],
#
#         [[9.44444478e-01],
#          [1.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [6.66666627e-01],
#          [0.00000000e+00],
#          [2.50000000e-01],
#          [0.00000000e+00],
#          [7.50000000e-01],
#          [3.33333343e-01],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [3.38461548e-01],
#          [2.44140625e-04],
#          [0.00000000e+00],
#          [3.23531739e-02],
#          [2.48420089e-02],
#          [4.99555945e-01],
#          [0.00000000e+00],
#          [8.38226676e-01],
#          [2.87726045e-01]],
#
#         [[9.44444478e-01],
#          [1.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [6.66666627e-01],
#          [0.00000000e+00],
#          [2.50000000e-01],
#          [0.00000000e+00],
#          [7.50000000e-01],
#          [3.33333343e-01],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [3.38461548e-01],
#          [2.44140625e-04],
#          [0.00000000e+00],
#          [3.23531739e-02],
#          [2.48420089e-02],
#          [4.99573082e-01],
#          [0.00000000e+00],
#          [8.38231325e-01],
#          [2.87728310e-01]],
#
#         [[9.44444478e-01],
#          [1.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [6.66666627e-01],
#          [0.00000000e+00],
#          [2.50000000e-01],
#          [0.00000000e+00],
#          [7.50000000e-01],
#          [3.33333343e-01],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [3.38461548e-01],
#          [4.88281250e-04],
#          [0.00000000e+00],
#          [3.23531739e-02],
#          [2.48420089e-02],
#          [4.99571800e-01],
#          [0.00000000e+00],
#          [8.38233948e-01],
#          [2.87729859e-01]],
#
#         [[9.44444478e-01],
#          [1.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [6.66666627e-01],
#          [0.00000000e+00],
#          [2.50000000e-01],
#          [0.00000000e+00],
#          [7.50000000e-01],
#          [3.33333343e-01],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [3.38461548e-01],
#          [6.10351562e-04],
#          [0.00000000e+00],
#          [3.23531739e-02],
#          [2.48420089e-02],
#          [4.99581546e-01],
#          [0.00000000e+00],
#          [8.38234663e-01],
#          [2.87736535e-01]],
#
#         [[9.44444478e-01],
#          [1.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [6.66666627e-01],
#          [0.00000000e+00],
#          [2.50000000e-01],
#          [0.00000000e+00],
#          [7.50000000e-01],
#          [3.33333343e-01],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [3.38461548e-01],
#          [6.10351562e-04],
#          [0.00000000e+00],
#          [3.23531739e-02],
#          [2.48420089e-02],
#          [4.99584049e-01],
#          [0.00000000e+00],
#          [8.38235974e-01],
#          [2.87737966e-01]],
#
#         [[9.44444478e-01],
#          [1.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [6.66666627e-01],
#          [0.00000000e+00],
#          [2.50000000e-01],
#          [0.00000000e+00],
#          [7.50000000e-01],
#          [3.33333343e-01],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [3.38461548e-01],
#          [7.32421875e-04],
#          [0.00000000e+00],
#          [3.23531739e-02],
#          [2.48420089e-02],
#          [4.99584168e-01],
#          [0.00000000e+00],
#          [8.38235557e-01],
#          [2.87736654e-01]],
#
#         [[9.44444478e-01],
#          [1.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [6.66666627e-01],
#          [0.00000000e+00],
#          [2.50000000e-01],
#          [0.00000000e+00],
#          [7.50000000e-01],
#          [3.33333343e-01],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [3.38461548e-01],
#          [8.54492188e-04],
#          [0.00000000e+00],
#          [3.23531739e-02],
#          [2.48420089e-02],
#          [4.99588042e-01],
#          [0.00000000e+00],
#          [8.38234425e-01],
#          [2.87733912e-01]],
#
#         [[9.44444478e-01],
#          [1.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [6.66666627e-01],
#          [0.00000000e+00],
#          [2.50000000e-01],
#          [0.00000000e+00],
#          [7.50000000e-01],
#          [3.33333343e-01],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [3.38461548e-01],
#          [9.76562500e-04],
#          [0.00000000e+00],
#          [3.23531739e-02],
#          [2.48420089e-02],
#          [4.99588966e-01],
#          [0.00000000e+00],
#          [8.38227868e-01],
#          [2.87738204e-01]],
#
#         [[9.44444478e-01],
#          [1.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [6.66666627e-01],
#          [0.00000000e+00],
#          [2.50000000e-01],
#          [0.00000000e+00],
#          [7.50000000e-01],
#          [3.33333343e-01],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [0.00000000e+00],
#          [3.38461548e-01],
#          [1.09863281e-03],
#          [0.00000000e+00],
#          [3.23531739e-02],
#          [2.48420089e-02],
#          [4.99591768e-01],
#          [0.00000000e+00],
#          [8.38228047e-01],
#          [2.87738204e-01]]]])

# %%
y_train[:2]
# Out:
# array([[0.],
#        [0.]], dtype=float32)

# %%
len(X_train), len(X_val)
# Out:
# (8822, 2197)

# %% [markdown]
# ### Define the input dimensions for the model architecture

# %%
def get_input_dims(X_train, exogenous_data_train):
    """
    计算输入维度和外生数据维度。

    参数:
    X_train: numpy.ndarray
        训练集数据，形状为 (样本数, 时间步数, 特征数)。
    exogenous_data_train: dict
        训练集的外生数据，包含不同区域或类别的外生数据。

    返回:
    input_dim: int
        输入维度。
    exogenous_dim: int
        外生数据维度。
    """
    # 根据模型类型计算输入维度
    if args.model_name == "mlp":
        # 如果是多层感知器模型，将时间步数和特征数展平
        input_dim = X_train.shape[1] * X_train.shape[2]
    else:
        # 否则，输入维度为特征数
        input_dim = X_train.shape[2]
    
    if exogenous_data_train is not None:
        if len(exogenous_data_train) == 1:
            cid = next(iter(exogenous_data_train.keys()))
            exogenous_dim = exogenous_data_train[cid].shape[1]
        else:
            exogenous_dim = exogenous_data_train["all"].shape[1]
    else:
        exogenous_dim = 0

    return input_dim, exogenous_dim

# %% [markdown]
# ### Initialize the model for training

# %%
def get_model(model: str,
              input_dim: int,
              out_dim: int,
              lags: int = 10,
              exogenous_dim: int = 0,
              seed=0):
    if model == "mlp":
        model = MLP(input_dim=input_dim, layer_units=[256, 128, 64], num_outputs=out_dim)
    elif model == "rnn":
        model = RNN(input_dim=input_dim, rnn_hidden_size=128, num_rnn_layers=1, rnn_dropout=0.0,
                    layer_units=[128], num_outputs=out_dim, matrix_rep=True, exogenous_dim=exogenous_dim)
    elif model == "lstm":
        model = LSTM(input_dim=input_dim, lstm_hidden_size=128, num_lstm_layers=1, lstm_dropout=0.0,
                     layer_units=[128], num_outputs=out_dim, matrix_rep=True, exogenous_dim=exogenous_dim)
    elif model == "gru":
        model = GRU(input_dim=input_dim, gru_hidden_size=128, num_gru_layers=1, gru_dropout=0.0,
                    layer_units=[128], num_outputs=out_dim, matrix_rep=True, exogenous_dim=exogenous_dim)
    elif model == "cnn":
        model = CNN(num_features=input_dim, lags=lags, exogenous_dim=exogenous_dim, out_dim=out_dim)
    elif model == "da_encoder_decoder":
        model = DualAttentionAutoEncoder(input_dim=input_dim, architecture="lstm", matrix_rep=True)
    else:
        raise NotImplementedError("Specified model is not implemented. Plese define your own model or choose one from ['mlp', 'rnn', 'lstm', 'gru', 'cnn', 'da_encoder_decoder']")
    return model

# %%
# define the model
args.model_name = "lstm"

input_dim, exogenous_dim = get_input_dims(X_train, exogenous_data_train)

print(input_dim, exogenous_dim)
model = get_model(model=args.model_name,
                  input_dim=input_dim,
                  out_dim=y_train.shape[1],
                  lags=args.num_lags,
                  exogenous_dim=exogenous_dim,
                  seed=args.seed)
# Out:
# 26 0

# %%
model
# Out:
# LSTM(
#   (lstm): LSTM(26, 128, batch_first=True)
#   (MLP_layers): Sequential(
#     (0): Linear(in_features=128, out_features=1, bias=True)
#   )
# )

# %% [markdown]
# ### The fit function used to train the model specified above

# %%
def fit(model, X_train, y_train, X_val, y_val, exogenous_data_train=None, exogenous_data_val=None, idxs=[13], log_per=1):
    
    # 获取外生数据（如果有）
    if exogenous_data_train is not None and len(exogenous_data_train) > 1:
        exogenous_data_train = exogenous_data_train["all"]
        exogenous_data_val = exogenous_data_val["all"]
    elif exogenous_data_train is not None and len(exogenous_data_train) == 1:
        cid = next(iter(exogenous_data_train.keys()))
        exogenous_data_train = exogenous_data_train[cid]
        exogenous_data_val = exogenous_data_val[cid]
    else:
        exogenous_data_train = None
        exogenous_data_val = None
    
    num_features = len(X_train[0][0])
    print(f"特征数: {num_features}")
    
    train_loader = to_torch_dataset(X_train, y_train, num_lags=args.num_lags, num_features=num_features, exogenous_data=exogenous_data_train, indices=idxs, batch_size=args.batch_size, shuffle=False)
    val_loader = to_torch_dataset(X_val, y_val, num_lags=args.num_lags, num_features=num_features, exogenous_data=exogenous_data_val, indices=idxs, batch_size=args.batch_size, shuffle=False)
    print(f"训练集数据加载器: {train_loader}")
    print(f"验证集数据加载器: {val_loader}")
    
    model = train(model, train_loader, val_loader, epochs=args.epochs, optimizer=args.optimizer, lr=args.lr, criterion=args.criterion, early_stopping=args.early_stopping, patience=args.patience, plot_history=args.plot_history, device=device, log_per=log_per)
    
    return model

# %%
# trained_model = fit(model, X_train, y_train, X_val, y_val)

# %%
#打印参数形状
print(X_train.shape)
print(y_train.shape)
print(X_val.shape)
print(y_val.shape)

model = fit(model, X_train, y_train, X_val, y_val, 
            exogenous_data_train=exogenous_data_train, exogenous_data_val=exogenous_data_val,idxs=[target_index])
# Out:
# (8822, 10, 26, 1)
# (8822, 1)
# (2197, 10, 26, 1)
# (2197, 1)
# 特征数: 26
# 训练集数据加载器: <torch.utils.data.dataloader.DataLoader object at 0x7fa7f2ba86d0>
# 验证集数据加载器: <torch.utils.data.dataloader.DataLoader object at 0x7fa810231df0>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/yanglin/Federated-Time-Series-Forecasting/notebooks/02.Individual_Training0604_hzh.ipynb 单元格 35 line 7
#       <a href='vscode-notebook-cell://ssh-remote%2B%E5%AE%9E%E9%AA%8C%E6%9C%BA%E5%99%A8/home/yanglin/Federated-Time-Series-Forecasting/notebooks/02.Individual_Training0604_hzh.ipynb#X50sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> print(X_val.shape)
#       <a href='vscode-notebook-cell://ssh-remote%2B%E5%AE%9E%E9%AA%8C%E6%9C%BA%E5%99%A8/home/yanglin/Federated-Time-Series-Forecasting/notebooks/02.Individual_Training0604_hzh.ipynb#X50sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> print(y_val.shape)
# ----> <a href='vscode-notebook-cell://ssh-remote%2B%E5%AE%9E%E9%AA%8C%E6%9C%BA%E5%99%A8/home/yanglin/Federated-Time-Series-Forecasting/notebooks/02.Individual_Training0604_hzh.ipynb#X50sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> model = fit(model, X_train, y_train, X_val, y_val,
#       <a href='vscode-notebook-cell://ssh-remote%2B%E5%AE%9E%E9%AA%8C%E6%9C%BA%E5%99%A8/home/yanglin/Federated-Time-Series-Forecasting/notebooks/02.Individual_Training0604_hzh.ipynb#X50sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a>             exogenous_data_train=exogenous_data_train, exogenous_data_val=exogenous_data_val,idxs=[target_index])
#
# /home/yanglin/Federated-Time-Series-Forecasting/notebooks/02.Individual_Training0604_hzh.ipynb 单元格 35 line 2
#      <a href='vscode-notebook-cell://ssh-remote%2B%E5%AE%9E%E9%AA%8C%E6%9C%BA%E5%99%A8/home/yanglin/Federated-Time-Series-Forecasting/notebooks/02.Individual_Training0604_hzh.ipynb#X50sdnNjb2RlLXJlbW90ZQ%3D%3D?line=19'>20</a> print(f"训练集数据加载器: {train_loader}")
#      <a href='vscode-notebook-cell://ssh-remote%2B%E5%AE%9E%E9%AA%8C%E6%9C%BA%E5%99%A8/home/yanglin/Federated-Time-Series-Forecasting/notebooks/02.Individual_Training0604_hzh.ipynb#X50sdnNjb2RlLXJlbW90ZQ%3D%3D?line=20'>21</a> print(f"验证集数据加载器: {val_loader}")
# ---> <a href='vscode-notebook-cell://ssh-remote%2B%E5%AE%9E%E9%AA%8C%E6%9C%BA%E5%99%A8/home/yanglin/Federated-Time-Series-Forecasting/notebooks/02.Individual_Training0604_hzh.ipynb#X50sdnNjb2RlLXJlbW90ZQ%3D%3D?line=22'>23</a> model = train(model, train_loader, val_loader, epochs=args.epochs, optimizer=args.optimizer, lr=args.lr, criterion=args.criterion, early_stopping=args.early_stopping, patience=args.patience, plot_history=args.plot_history, device=device, log_per=log_per)
#      <a href='vscode-notebook-cell://ssh-remote%2B%E5%AE%9E%E9%AA%8C%E6%9C%BA%E5%99%A8/home/yanglin/Federated-Time-Series-Forecasting/notebooks/02.Individual_Training0604_hzh.ipynb#X50sdnNjb2RlLXJlbW90ZQ%3D%3D?line=24'>25</a> return model
#
# File /home/yanglin/Federated-Time-Series-Forecasting/ml/utils/train_utils.py:270, in train(model, train_loader, test_loader, epochs, optimizer, lr, reg1, reg2, max_grad_norm, criterion, early_stopping, patience, plot_history, device, fedprox_mu, log_per, use_carbontracker)
#     268     epoch_loss.append(loss.item())
#     269 train_loss = sum(epoch_loss) / len(epoch_loss)
# --> 270 _, train_mse, train_rmse, train_mae, train_r2, train_nrmse = test(model, train_loader, criterion, device)
#     271 test_loss, test_mse, test_rmse, test_mae, test_r2, test_nrmse = test(model, test_loader, criterion, device)
#     272 if (epoch + 1) % log_per == 0:
#
# File /home/yanglin/Federated-Time-Series-Forecasting/ml/utils/train_utils.py:343, in test(model, data, criterion, device)
#     341 y_true = torch.stack(y_true)
#     342 y_pred = torch.stack(y_pred)
# --> 343 mse, rmse, mae, r2, nrmse = accumulate_metric(y_true.cpu(), y_pred.cpu())
#     344 if criterion is None:
#     345     return mse, rmse, mae, r2, nrmse, y_pred
#
# File /home/yanglin/Federated-Time-Series-Forecasting/ml/utils/helpers.py:86, in accumulate_metric(y_true, y_pred, log_per_output, dims, return_all)
#      83 mae = mean_absolute_error(y_true, y_pred)
#      84 r2 = r2_score(y_true, y_pred)
# ---> 86 y_true_first_dim = y_true[:, dims[0]]
#      87 y_pred_first_dim = y_pred[:, dims[0]]
#      89 rmse_first_dim = math.sqrt(mean_squared_error(y_true_first_dim, y_pred_first_dim))
#
# IndexError: index 3 is out of bounds for axis 1 with size 1
